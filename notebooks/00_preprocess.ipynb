# %% [markdown]
# ## Download the database

# %%
data_dir = '../data'
data_raw = data_dir + '/raw/filmes.csv'

# !wget --no-check-certificate -nc 'https://docs.google.com/uc?export=download&id=1AeYgV89TmYvNC__RDXr8hS0P6WOsChWg' -O $data_raw
# Out:
# File ‘../data/raw/filmes.csv’ already there; not retrieving.

# %% [markdown]
# ## Install the dependencies

# %%
# %pip install \
    pandas \
    unidecode \
    spacy \
    matplotlib

# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: pandas in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: unidecode in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (1.3.8)
# Requirement already satisfied: spacy in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (3.8.4)
# Requirement already satisfied: matplotlib in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: numpy>=1.23.2 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (2.10.6)
# Requirement already satisfied: jinja2 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (3.1.5)
# Requirement already satisfied: setuptools in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (66.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: language-data>=1.2 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: six>=1.5 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: wrapt in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /home/srjheam/projects/ufes-cdados-movie-synopsis-clustering/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 2.7 MB/s eta 0:00:0000:0100:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## Import the dataset

# %%
import pandas as pd

# %%
df = pd.read_csv(data_raw)
    #.sample(1, random_state=42)

# %%
df.shape
# Out:
# (30358, 9)

# %%
df.head()
# Out:
#            genres  averageRating  numVotes  \
# 0          Family            7.1    387992
# 1         Romance            6.7     30265
# 2         Romance            6.0     12585
# 3  Romance,Family            6.1     42555
# 4    Crime,Action            8.3    738636
#
#                                              sinopse  \
# 0  When two kids find and play a magical board ga...
# 1  John and Max resolve to save their beloved bai...
# 2  Based on Terry McMillan's novel, this film fol...
# 3  George Banks must deal not only with his daugh...
# 4  A group of high-end professional thieves start...
#
#                   primaryTitle  startYear runtimeMinutes  \
# 0                      Jumanji       1995            104
# 1             Grumpier Old Men       1995            101
# 2            Waiting to Exhale       1995            124
# 3  Father of the Bride Part II       1995            106
# 4                         Heat       1995            170
#
#                                         actors_names      directors_names
# 0  ['Robin Williams' 'Jonathan Hyde' 'Jonathan Hy...     ['Joe Johnston']
# 1  ['Walter Matthau' 'Jack Lemmon' 'Burgess Mered...    ['Howard Deutch']
# 2  ['Gregory Hines' 'Dennis Haysbert' 'Mykelti Wi...  ['Forest Whitaker']
# 3  ['Steve Martin' 'Martin Short' 'George Newbern...    ['Charles Shyer']
# 4  ['Al Pacino' 'Robert De Niro' 'Val Kilmer' 'Jo...     ['Michael Mann']

# %% [markdown]
# ## Preprocess the data

# %%
df.isnull().sum()

# Como não há valores nulos, não removemos nenhuma linha
# Out:
# genres             0
# averageRating      0
# numVotes           0
# sinopse            0
# primaryTitle       0
# startYear          0
# runtimeMinutes     0
# actors_names       0
# directors_names    0
# dtype: int64

# %% [markdown]
# ### Preprocess genres

# %%
df['genres_list'] = df['genres'].apply(lambda x: x.split(','))

# %%
df['genres_list'].explode().value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='genres_list'>

# %% [markdown]
# ### Preprocess synopses

# %%
df['sinopse_clean'] = df['sinopse']

df[['sinopse', 'sinopse_clean']].head()
# Out:
#                                              sinopse  \
# 0  When two kids find and play a magical board ga...
# 1  John and Max resolve to save their beloved bai...
# 2  Based on Terry McMillan's novel, this film fol...
# 3  George Banks must deal not only with his daugh...
# 4  A group of high-end professional thieves start...
#
#                                        sinopse_clean
# 0  When two kids find and play a magical board ga...
# 1  John and Max resolve to save their beloved bai...
# 2  Based on Terry McMillan's novel, this film fol...
# 3  George Banks must deal not only with his daugh...
# 4  A group of high-end professional thieves start...

# %%
# lower case
df['sinopse_clean'] = df['sinopse_clean'].apply(str.lower)

df[['sinopse', 'sinopse_clean']].head()
# Out:
#                                              sinopse  \
# 0  When two kids find and play a magical board ga...
# 1  John and Max resolve to save their beloved bai...
# 2  Based on Terry McMillan's novel, this film fol...
# 3  George Banks must deal not only with his daugh...
# 4  A group of high-end professional thieves start...
#
#                                        sinopse_clean
# 0  when two kids find and play a magical board ga...
# 1  john and max resolve to save their beloved bai...
# 2  based on terry mcmillan's novel, this film fol...
# 3  george banks must deal not only with his daugh...
# 4  a group of high-end professional thieves start...

# %%
# normalize special characters

from unidecode import unidecode

df['sinopse_clean'] = [unidecode(c).lower() for c in df['sinopse_clean']]

# they are rare and I'm bad at pandas so I couldn't filter out the difference and show

# %%
# remove non-alpha and punctuation, except for apostrophes
import re

df['sinopse_clean'] = [re.sub(r'[^a-z\s\']', '', c) for c in df['sinopse_clean']]

df[['sinopse', 'sinopse_clean']].head()
# Out:
#                                              sinopse  \
# 0  When two kids find and play a magical board ga...
# 1  John and Max resolve to save their beloved bai...
# 2  Based on Terry McMillan's novel, this film fol...
# 3  George Banks must deal not only with his daugh...
# 4  A group of high-end professional thieves start...
#
#                                        sinopse_clean
# 0  when two kids find and play a magical board ga...
# 1  john and max resolve to save their beloved bai...
# 2  based on terry mcmillan's novel this film foll...
# 3  george banks must deal not only with his daugh...
# 4  a group of highend professional thieves start ...

# %%
# lemmatize and tokenize

import spacy

nlp = spacy.load('en_core_web_sm')

docs = [nlp(sinopse) for sinopse in df['sinopse_clean']]

df['sinopse_tokens'] = [[token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct and not token.is_space] for doc in docs]

df[['sinopse_clean', 'sinopse_tokens']].head()
# Out:
#                                        sinopse_clean  \
# 0  when two kids find and play a magical board ga...
# 1  john and max resolve to save their beloved bai...
# 2  based on terry mcmillan's novel this film foll...
# 3  george banks must deal not only with his daugh...
# 4  a group of highend professional thieves start ...
#
#                                       sinopse_tokens
# 0  [kid, find, play, magical, board, game, releas...
# 1  [john, max, resolve, save, beloved, bait, shop...
# 2  [base, terry, mcmillan, novel, film, follow, d...
# 3    [george, bank, deal, daughter, pregnancy, wife]
# 4  [group, highend, professional, thief, start, f...

# %%
# tokenize (nltk)
#   ignore due to spacy lemmatization

#import nltk
#nltk.download('punkt_tab')
#
#df['sinopse_tokens'] = df['sinopse_clean'].apply(nltk.word_tokenize)
#
#df[['sinopse_clean', 'sinopse_tokens']].head()

# %%
# remove aphostrophes
#   ignored due to lemmatization

#df['sinopse_tokens'] = df['sinopse_tokens'].apply(lambda x: [t for t in x if t != "'"])
#
#df[['sinopse_clean', 'sinopse_tokens']].head()

# %%
# remove stopwords
#   ignore due to lemmatization

#nltk.download('stopwords')
#
#stop_words = set(nltk.corpus.stopwords.words('english'))
#
#df['sinopse_tokens'] = df['sinopse_tokens'].apply(lambda x: [w for w in x if not w in stop_words])
#
#df[['sinopse_clean', 'sinopse_tokens']].head()

# %% [markdown]
# ## Save the preprocessed data

# %%
data_processed_dir = data_dir + '/processed'

# !mkdir -p $data_processed_dir

data_processed = data_dir + '/processed/filmes.csv'

df.to_csv(data_processed, index=False)
